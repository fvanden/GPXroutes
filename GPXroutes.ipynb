# %%
import os
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from IPython.display import FileLink, FileLinks

import trackanimation
from trackanimation.animation import AnimationTrack
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-4519dc68a9d6> in <module>()
#       6 from IPython.display import FileLink, FileLinks
#       7
# ----> 8 import trackanimation
#       9 from trackanimation.animation import AnimationTrack
#
# ImportError: No module named 'trackanimation'

# %%
input_directory = "example-routes/Track_CAMPO DI BLENIO 030218.gpx"
ibiza_trk = trackanimation.read_track(input_directory)

#fig = AnimationTrack(df_points=ibiza_trk, dpi=100, bg_map=True, map_transparency=0.5)
#fig.make_video(output_file='simple-example', framerate=60, linewidth=1.0)


fig = AnimationTrack(df_points=ibiza_trk, dpi=100, bg_map=False, map_transparency=0.5)
fig.make_map(output_file='my_track')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7a6280bbe73b> in <module>()
#       1 input_directory = "example-routes/Track_CAMPO DI BLENIO 030218.gpx"
# ----> 2 ibiza_trk = trackanimation.read_track(input_directory)
#       3
#       4 #fig = AnimationTrack(df_points=ibiza_trk, dpi=100, bg_map=True, map_transparency=0.5)
#       5 #fig.make_video(output_file='simple-example', framerate=60, linewidth=1.0)
#
# NameError: name 'trackanimation' is not defined

# %%
FileLinks('.')
# Out:
# ./
#   environment.yml
#   environment.yml~
#   GPXroutes.ipynb
# ./.git/
#   index
#   config
#   HEAD
#   COMMIT_EDITMSG
#   description
# ./.git/hooks/
#   prepare-commit-msg.sample
#   commit-msg.sample
#   applypatch-msg.sample
#   pre-push.sample
#   pre-applypatch.sample
#   post-update.sample
#   pre-rebase.sample
#   pre-commit.sample
#   update.sample
# ./.git/info/
#   exclude
# ./.git/logs/
#   HEAD
# ./.git/logs/refs/heads/
#   master
# ./.git/logs/refs/remotes/origin/
#   master
# ./.git/objects/0c/
#   cd44e5e9fcce1baea363ebe9813b80a92da220
# ./.git/objects/0f/
#   33e1ac96abe724d9c2205d4e6726de8bab8072
# ./.git/objects/11/
#   b74b9249ab08d12f2f2f70d6cdffdfaa57eddb
# ./.git/objects/2d/
#   1a32c216752efb4e7adbf3f0bda6ed5462ae74
# ./.git/objects/3a/
#   47cf4492afb30f9f427fd7a3ebd89a40998cd3
# ./.git/objects/3c/
#   3d1d4c2e1f24a55e29308eb67759a1332dc309
# ./.git/objects/4b/
#   0b2e12fff149c0a44a2ab0a7fe2417b6b01d71
# ./.git/objects/55/
# ...
